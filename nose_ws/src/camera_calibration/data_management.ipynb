# %%
import numpy as np
import cv2
import os

# %%
# change input ounput txt to manage your file

# %%
name = 'point5.txt'
path = 'cal_0223/'
f = open(path+name, 'r')

text = f.read()
print(text)
f.close()
# Out:
# transforms:
#   -
#     header:
#       seq: 0
#       stamp:
#         secs: 0
#         nsecs:         0
#       frame_id: ''
#     child_frame_id: "tag_1"
#     transform:
#       translation:
#         x: 0.464355234843
#         y: -0.133929276555
#         z: 1.12865998859
#       rotation:
#         x: 0.994945139014
#         y: -0.0256613531288
#         z: 0.0823290451029
#         w: 0.0514547727599
# ---
# transforms:
#   -
#     header:
#       seq: 0
#       stamp:
#         secs: 0
#         nsecs:         0
#       frame_id: ''
#     child_frame_id: "tag_1"
#     transform:
#       translation:
#         x: 0.464524912277
#         y: -0.133983256643
#         z: 1.12910219901
#       rotation:
#         x: 0.994929045595
#         y: -0.0266714048148
#         z: 0.0823427991728
#         w: 0.0512298137956
# ---
# transforms:
#   -
#     header:
#       seq: 0
#       stamp:
#         secs: 0
#         nsecs:         0
#       frame_id: ''
#     child_frame_id: "tag_1"
#     transform:
#       translation:
#         x: 0.464393905654
#         y: -0.133942579062
#         z: 1.12876041386
#       rotation:
#         x: 0.994962342469
#         y: -0.0258520274775
#         z: 0.0820557722276
#         w: 0.0514631906063
# ---
# transforms:
#   -
#     header:
#       seq: 0
#       stamp:
#         secs: 0
#         nsecs:         0
#       frame_id: ''
#     child_frame_id: "tag_1"
#     transform:
#       translation:
#         x: 0.464523870567
#         y: -0.134011148628
#         z: 1.12910789447
#       rotation:
#         x: 0.994993181706
#         y: -0.0262380193862
#         z: 0.0820517996425
#         w: 0.050671854837
# ---
# transforms:
#   -
#     header:
#       seq: 0
#       stamp:
#         secs: 0
#         nsecs:         0
#       frame_id: ''
#     child_frame_id: "tag_1"
#     transform:
#       translation:
#         x: 0.464087196767
#         y: -0.133870073227
#         z: 1.12814188885
#       rotation:
#         x: 0.994915763451
#         y: -0.0267626810087
#         z: 0.081444177737
#         w: 0.0528510024038
# ---
# transforms:
#   -
#     header:
#       seq: 0
#       stamp:
#         secs: 0
#         nsecs:         0
#       frame_id: ''
#     child_frame_id: "tag_1"
#     transform:
#       translation:
#         x: 0.464349317752
#         y: -0.133941358548
#         z: 1.12862104317
#       rotation:
#         x: 0.994948602476
#         y: -0.0265693839774
#         z: 0.0828223198075
#         w: 0.0501179569394
# ---
# transforms:
#   -
#     header:
#       seq: 0
#       stamp:
#         secs: 0
#         nsecs:         0
#       frame_id: ''
#     child_frame_id: "tag_1"
#     transform:
#       translation:
#         x: 0.464217214782
#         y: -0.133900148098
#         z: 1.12836905968
#       rotation:
#         x: 0.994901359087
#         y: -0.0266741073381
#         z: 0.0821354936989
#         w: 0.0520916342525
# ---
# transforms:
#   -
#     header:
#       seq: 0
#       stamp:
#         secs: 0
#         nsecs:         0
#       frame_id: ''
#     child_frame_id: "tag_1"
#     transform:
#       translation:
#         x: 0.464342883033
#         y: -0.133940887737
#         z: 1.12867250952
#       rotation:
#         x: 0.994935964508
#         y: -0.0264929292665
#         z: 0.0817007986691
#         w: 0.0522066157175
# ---
# transforms:
#   -
#     header:
#       seq: 0
#       stamp:
#         secs: 0
#         nsecs:         0
#       frame_id: ''
#     child_frame_id: "tag_1"
#     transform:
#       translation:
#         x: 0.464583635918
#         y: -0.134014795265
#         z: 1.12925180217
#       rotation:
#         x: 0.995015784772
#         y: -0.0261763846365
#         z: 0.0820011066096
#         w: 0.0503408726246
# ---
# transforms:
#   -
#     header:
#       seq: 0
#       stamp:
#         secs: 0
#         nsecs:         0
#       frame_id: ''
#     child_frame_id: "tag_1"
#     transform:
#       translation:
#         x: 0.464056752118
#         y: -0.133864059603
#         z: 1.12804732689
#       rotation:
#         x: 0.994835923682
#         y: -0.0265016078578
#         z: 0.0823362933399
#         w: 0.0531025849771
# ---
# transforms:
#   -
#     header:
#       seq: 0
#       stamp:
#         secs: 0
#         nsecs:         0
#       frame_id: ''
#     child_frame_id: "tag_1"
#     transform:
#       translation:
#         x: 0.464189327195
#         y: -0.133904979781
#         z: 1.12831814147
#       rotation:
#         x: 0.994902983556
#         y: -0.0262409805291
#         z: 0.082310896476
#         w: 0.0520036592247
# ---
# transforms:
#   -
#     header:
#       seq: 0
#       stamp:
#         secs: 0
#         nsecs:         0
#       frame_id: ''
#     child_frame_id: "tag_1"
#     transform:
#       translation:
#         x: 0.464351707684
#         y: -0.133919013807
#         z: 1.12865766621
#       rotation:
#         x: 0.99484979569
#         y: -0.0267033772364
#         z: 0.0826134565349
#         w: 0.0523051666486
# ---
# transforms:
#   -
#     header:
#       seq: 0
#       stamp:
#         secs: 0
#         nsecs:         0
#       frame_id: ''
#     child_frame_id: "tag_1"
#     transform:
#       translation:
#         x: 0.464437693781
#         y: -0.13397411956
#         z: 1.12895064634
#       rotation:
#         x: 0.994999500223
#         y: -0.0268075678155
#         z: 0.0813542954645
#         w: 0.0513695189182
# ---
# transforms:
#   -
#     header:
#       seq: 0
#       stamp:
#         secs: 0
#         nsecs:         0
#       frame_id: ''
#     child_frame_id: "tag_1"
#     transform:
#       translation:
#         x: 0.464140374405
#         y: -0.13389120392
#         z: 1.12820316905
#       rotation:
#         x: 0.994888571171
#         y: -0.0264573619182
#         z: 0.0820721917709
#         w: 0.0525442127304
# ---
# transforms:
#   -
#     header:
#       seq: 0
#       stamp:
#         secs: 0
#         nsecs:         0
#       frame_id: ''
#     child_frame_id: "tag_1"
#     transform:
#       translation:
#         x: 0.464308627519
#         y: -0.133919941146
#         z: 1.12857290279
#       rotation:
#         x: 0.994910986309
#         y: -0.0262341275796
#         z: 0.0819737910377
#         w: 0.0523850881038
# ---
# transforms:
#   -
#     header:
#       seq: 0
#       stamp:
#         secs: 0
#         nsecs:         0
#       frame_id: ''
#     child_frame_id: "tag_1"
#     transform:
#       translation:
#         x: 0.464254748609
#         y: -0.133916314736
#         z: 1.12841029803
#       rotation:
#         x: 0.994929393228
#         y: -0.0258169349249
#         z: 0.0821822753756
#         w: 0.0519139863189
# ---
# transforms:
#   -
#     header:
#       seq: 0
#       stamp:
#         secs: 0
#         nsecs:         0
#       frame_id: ''
#     child_frame_id: "tag_1"
#     transform:
#       translation:
#         x: 0.464606718931
#         y: -0.133998324931
#         z: 1.12934981695
#       rotation:
#         x: 0.995008471861
#         y: -0.0262913725083
#         z: 0.0815182547782
#         w: 0.051202331918
# ---
# transforms:
#   -
#     header:
#       seq: 0
#       stamp:
#         secs: 0
#         nsecs:         0
#       frame_id: ''
#     child_frame_id: "tag_1"
#     transform:
#       translation:
#         x: 0.464200537786
#         y: -0.133903030161
#         z: 1.12834134919
#       rotation:
#         x: 0.994986621727
#         y: -0.0264869252673
#         z: 0.0816671742537
#         w: 0.0512887709269
# ---
# transforms:
#   -
#     header:
#       seq: 0
#       stamp:
#         secs: 0
#         nsecs:         0
#       frame_id: ''
#     child_frame_id: "tag_1"
#     transform:
#       translation:
#         x: 0.464299191227
#         y: -0.133933903423
#         z: 1.1285863407
#       rotation:
#         x: 0.994962373185
#         y: -0.0268251797075
#         z: 0.0817216742259
#         w: 0.0514961517188

# %%
newtext = text.split("\n")
print(newtext)
# Out:
# ['transforms: ', '  - ', '    header: ', '      seq: 0', '      stamp: ', '        secs: 0', '        nsecs:         0', "      frame_id: ''", '    child_frame_id: "tag_1"', '    transform: ', '      translation: ', '        x: 0.464355234843', '        y: -0.133929276555', '        z: 1.12865998859', '      rotation: ', '        x: 0.994945139014', '        y: -0.0256613531288', '        z: 0.0823290451029', '        w: 0.0514547727599', '---', 'transforms: ', '  - ', '    header: ', '      seq: 0', '      stamp: ', '        secs: 0', '        nsecs:         0', "      frame_id: ''", '    child_frame_id: "tag_1"', '    transform: ', '      translation: ', '        x: 0.464524912277', '        y: -0.133983256643', '        z: 1.12910219901', '      rotation: ', '        x: 0.994929045595', '        y: -0.0266714048148', '        z: 0.0823427991728', '        w: 0.0512298137956', '---', 'transforms: ', '  - ', '    header: ', '      seq: 0', '      stamp: ', '        secs: 0', '        nsecs:         0', "      frame_id: ''", '    child_frame_id: "tag_1"', '    transform: ', '      translation: ', '        x: 0.464393905654', '        y: -0.133942579062', '        z: 1.12876041386', '      rotation: ', '        x: 0.994962342469', '        y: -0.0258520274775', '        z: 0.0820557722276', '        w: 0.0514631906063', '---', 'transforms: ', '  - ', '    header: ', '      seq: 0', '      stamp: ', '        secs: 0', '        nsecs:         0', "      frame_id: ''", '    child_frame_id: "tag_1"', '    transform: ', '      translation: ', '        x: 0.464523870567', '        y: -0.134011148628', '        z: 1.12910789447', '      rotation: ', '        x: 0.994993181706', '        y: -0.0262380193862', '        z: 0.0820517996425', '        w: 0.050671854837', '---', 'transforms: ', '  - ', '    header: ', '      seq: 0', '      stamp: ', '        secs: 0', '        nsecs:         0', "      frame_id: ''", '    child_frame_id: "tag_1"', '    transform: ', '      translation: ', '        x: 0.464087196767', '        y: -0.133870073227', '        z: 1.12814188885', '      rotation: ', '        x: 0.994915763451', '        y: -0.0267626810087', '        z: 0.081444177737', '        w: 0.0528510024038', '---', 'transforms: ', '  - ', '    header: ', '      seq: 0', '      stamp: ', '        secs: 0', '        nsecs:         0', "      frame_id: ''", '    child_frame_id: "tag_1"', '    transform: ', '      translation: ', '        x: 0.464349317752', '        y: -0.133941358548', '        z: 1.12862104317', '      rotation: ', '        x: 0.994948602476', '        y: -0.0265693839774', '        z: 0.0828223198075', '        w: 0.0501179569394', '---', 'transforms: ', '  - ', '    header: ', '      seq: 0', '      stamp: ', '        secs: 0', '        nsecs:         0', "      frame_id: ''", '    child_frame_id: "tag_1"', '    transform: ', '      translation: ', '        x: 0.464217214782', '        y: -0.133900148098', '        z: 1.12836905968', '      rotation: ', '        x: 0.994901359087', '        y: -0.0266741073381', '        z: 0.0821354936989', '        w: 0.0520916342525', '---', 'transforms: ', '  - ', '    header: ', '      seq: 0', '      stamp: ', '        secs: 0', '        nsecs:         0', "      frame_id: ''", '    child_frame_id: "tag_1"', '    transform: ', '      translation: ', '        x: 0.464342883033', '        y: -0.133940887737', '        z: 1.12867250952', '      rotation: ', '        x: 0.994935964508', '        y: -0.0264929292665', '        z: 0.0817007986691', '        w: 0.0522066157175', '---', 'transforms: ', '  - ', '    header: ', '      seq: 0', '      stamp: ', '        secs: 0', '        nsecs:         0', "      frame_id: ''", '    child_frame_id: "tag_1"', '    transform: ', '      translation: ', '        x: 0.464583635918', '        y: -0.134014795265', '        z: 1.12925180217', '      rotation: ', '        x: 0.995015784772', '        y: -0.0261763846365', '        z: 0.0820011066096 ...

# %%
output_path = path +'output_' + name
f = open(output_path,'w')
cnt = 0

i = 0
f.writelines('tag_0\n')
while i < len(newtext):
    if newtext[i] == '    child_frame_id: "tag_0"':
        print(newtext[i])
#         print(newtext[i+3],newtext[i+4],newtext[i+5],newtext[i+7],newtext[i+8],newtext[i+9],newtext[i+10])
        tag_1 = newtext[i+3].replace('x: ','') + newtext[i+4].replace('y: ','') + newtext[i+5].replace('z: ','') + newtext[i+7].replace('x: ','') + newtext[i+8].replace('y: ','') + newtext[i+9].replace('z: ','') + newtext[i+10].replace('w: ','') 
#         print(tag_1)
        f.writelines(tag_1 + '\n')
        cnt = cnt +1
    i=i+1


i = 0
f.writelines('tag_1\n')
while i < len(newtext):
    if newtext[i] == '    child_frame_id: "tag_1"':
        print(newtext[i])
#         print(newtext[i+3],newtext[i+4],newtext[i+5],newtext[i+7],newtext[i+8],newtext[i+9],newtext[i+10])
        tag_1 = newtext[i+3].replace('x: ','') + newtext[i+4].replace('y: ','') + newtext[i+5].replace('z: ','') + newtext[i+7].replace('x: ','') + newtext[i+8].replace('y: ','') + newtext[i+9].replace('z: ','') + newtext[i+10].replace('w: ','') 
#         print(tag_1)
        f.writelines(tag_1 + '\n')
        cnt = cnt +1
    i=i+1

    
i = 0
f.writelines('tag_2\n')

while i < len(newtext):
    if newtext[i] == '    child_frame_id: "tag_2"':
        print(newtext[i])
#         print(newtext[i+3],newtext[i+4],newtext[i+5],newtext[i+7],newtext[i+8],newtext[i+9],newtext[i+10])
        tag_1 = newtext[i+3].replace('x: ','') + newtext[i+4].replace('y: ','') + newtext[i+5].replace('z: ','') + newtext[i+7].replace('x: ','') + newtext[i+8].replace('y: ','') + newtext[i+9].replace('z: ','') + newtext[i+10].replace('w: ','') 
#         print(tag_1)
        f.writelines(tag_1 + '\n')
        cnt = cnt +1
    i=i+1
    
    
i = 0
f.writelines('tag_3\n')

while i < len(newtext):
    if newtext[i] == '    child_frame_id: "tag_3"':
        print(newtext[i])
#         print(newtext[i+3],newtext[i+4],newtext[i+5],newtext[i+7],newtext[i+8],newtext[i+9],newtext[i+10])
        tag_1 = newtext[i+3].replace('x: ','') + newtext[i+4].replace('y: ','') + newtext[i+5].replace('z: ','') + newtext[i+7].replace('x: ','') + newtext[i+8].replace('y: ','') + newtext[i+9].replace('z: ','') + newtext[i+10].replace('w: ','') 
#         print(tag_1)
        f.writelines(tag_1 + '\n')
        cnt = cnt +1
    i=i+1   
    
    
i = 0
f.writelines('tag_4\n')

while i < len(newtext):
    if newtext[i] == '    child_frame_id: "tag_4"':
        print(newtext[i])
#         print(newtext[i+3],newtext[i+4],newtext[i+5],newtext[i+7],newtext[i+8],newtext[i+9],newtext[i+10])
        tag_1 = newtext[i+3].replace('x: ','') + newtext[i+4].replace('y: ','') + newtext[i+5].replace('z: ','') + newtext[i+7].replace('x: ','') + newtext[i+8].replace('y: ','') + newtext[i+9].replace('z: ','') + newtext[i+10].replace('w: ','') 
#         print(tag_1)
        f.writelines(tag_1 + '\n')
        cnt = cnt +1
    i=i+1

    
i = 0
f.writelines('tag_5\n')

while i < len(newtext):
    if newtext[i] == '    child_frame_id: "tag_5"':
        print(newtext[i])
#         print(newtext[i+3],newtext[i+4],newtext[i+5],newtext[i+7],newtext[i+8],newtext[i+9],newtext[i+10])
        tag_1 = newtext[i+3].replace('x: ','') + newtext[i+4].replace('y: ','') + newtext[i+5].replace('z: ','') + newtext[i+7].replace('x: ','') + newtext[i+8].replace('y: ','') + newtext[i+9].replace('z: ','') + newtext[i+10].replace('w: ','') 
#         print(tag_1)
        f.writelines(tag_1 + '\n')
        cnt = cnt +1
    i=i+1

f.close()
# Out:
#     child_frame_id: "tag_1"
#     child_frame_id: "tag_1"
#     child_frame_id: "tag_1"
#     child_frame_id: "tag_1"
#     child_frame_id: "tag_1"
#     child_frame_id: "tag_1"
#     child_frame_id: "tag_1"
#     child_frame_id: "tag_1"
#     child_frame_id: "tag_1"
#     child_frame_id: "tag_1"
#     child_frame_id: "tag_1"
#     child_frame_id: "tag_1"
#     child_frame_id: "tag_1"
#     child_frame_id: "tag_1"
#     child_frame_id: "tag_1"
#     child_frame_id: "tag_1"
#     child_frame_id: "tag_1"
#     child_frame_id: "tag_1"
#     child_frame_id: "tag_1"
